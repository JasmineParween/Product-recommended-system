# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../datasets/main_data.csv')

# %%
df
# Out:
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# 1      http://www.flipkart.com/fabhomedecor-fabric-do...
# 2      http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3      http://www.flipkart.com/sicons-all-purpose-arn...
# 4      http://www.flipkart.com/eternal-gandhi-super-s...
# ...                                                  ...
# 12671  http://www.flipkart.com/purple-women-heels/p/i...
# 12672  http://www.flipkart.com/uberlyfe-large-vinyl-s...
# 12673  http://www.flipkart.com/witches-comfy-hues-wom...
# 12674  http://www.flipkart.com/stylistry-women-heels/...
# 12675  http://www.flipkart.com/uberlyfe-extra-large-v...
#
#                                             product_name  discounted_price  \
# 0                    Alisha Solid Women's Cycling Shorts             379.0
# 1                    FabHomeDecor Fabric Double Sofa Bed           22646.0
# ...

# %%
temp = df[df['product_category'] == 'Watches'][['product_name','product_name_val','img']]

# %%
temp = temp.reset_index(drop=True)

temp.head()
# Out:
#                                         product_name  \
# 0  Cobra Paris CO6394A1 Analog Watch  - For Men, ...
# 1  Aries Gold G 729 S-BK Analog Watch  - For Men,...
# 2  Maserati Time R8851116001 Analog Watch  - For ...
# 3  Vizion 8503B-1RED Cold Light Digital Watch  - ...
# 4  Camerii WM64 Elegance Analog Watch  - For Men,...
#
#                                     product_name_val  \
# 0         cobra paris co6394a1 analog watch men boys
# 1         aries gold g 729 sbk analog watch men boys
# 2        maserati time r8851116001 analog watch boys
# 3  vizion 8503b1red cold light digital watch boys...
# 4        camerii wm64 elegance analog watch men boys
#
#                                                  img
# 0  http://img6a.flixcart.com/image/watch/s/y/x/co...
# 1  http://img6a.flixcart.com/image/watch/v/d/5/g-...
# 2  http://img5a.flixcart.com/image/watch/a/y/m/r8...
# 3  http://img5a.flixcart.com/image/watch/g/s/q/85...
# 4  http://img5a.flixcart.com/image/watch/g/b/z/wm...

# %%
for i in temp.index[:]:
#     print(temp.iloc[i]['product_name'].split(",")[0])
    print(temp.iloc[i]['product_name'].split(",")[0])
# Out:
# Cobra Paris CO6394A1 Analog Watch  - For Men
# Aries Gold G 729 S-BK Analog Watch  - For Men
# Maserati Time R8851116001 Analog Watch  - For Boys
# Vizion 8503B-1RED Cold Light Digital Watch  - For Boys
# Camerii WM64 Elegance Analog Watch  - For Men
# Colat COLAT_MW20 Sheen Analog Watch  - For Men
# Rochees RW38 Analog Watch  - For Boys
# Rorlig RR-028 Expedition Analog Watch  - For Men
# T STAR UFT-TSW-005-BK-BR Analog Watch  - For Boys
# Alfajr WY16B Youth Digital Watch  - For Men
# TAG Heuer CAU1116.BA0858 Formula 1 Analog Watch  - For Boys
# Costa Swiss CS-2001 Analog Watch  - For Boys
# Breitling AB011010/BB08 131S Chronomat 44 Analog Watch  - For Boys
# Calibro SW-125 Analog-Digital Watch  - For Men
# Rochees RW50 Analog Watch  - For Boys
# Fluid DMF-002-GR01 Digital Watch  - For Boys
# Rorlig RR-030 Essentials Analog Watch  - For Men
# Disney DW100230 Digital Watch  - For Boys
# Cartier W6701005 Analog Watch  - For Boys
# Lois Caron LCS-4032 Analog Watch  - For Boys
# ...

# %%
res
# Out:
#                                         product_name  \
# 2  Maserati Time R8851116001 Analog Watch  - For ...
# 3  Vizion 8503B-1RED Cold Light Digital Watch  - ...
# 4  Camerii WM64 Elegance Analog Watch  - For Men,...
#
#                                     product_name_val  \
# 2        maserati time r8851116001 analog watch boys
# 3  vizion 8503b1red cold light digital watch boys...
# 4        camerii wm64 elegance analog watch men boys
#
#                                                  img
# 2  http://img5a.flixcart.com/image/watch/a/y/m/r8...
# 3  http://img5a.flixcart.com/image/watch/g/s/q/85...
# 4  http://img5a.flixcart.com/image/watch/g/b/z/wm...

# %%
print(temp.iloc[temp.index[-1]]['product_name'].split(",")[0])
# Out:
# Like Analog Purple Clock
